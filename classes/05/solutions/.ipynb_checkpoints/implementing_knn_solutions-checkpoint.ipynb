# %% [markdown]
# # This lab focuses on implementing kNN for classification

# %% [markdown]
# ### We will learn through the spirit of friendly competition!

# %% [markdown]
# [Here's](https://en.wikipedia.org/wiki/Iris_flower_data_set) a description of our first dataset
#
# The files of interest are called iris_train.csv and iris_test.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !head ../data/iris_train.csv
# Out:
# Sepal.Length,Sepal.Width,Petal.Length,Petal.Width,Species
# 5.0,2.0,3.5,1.0,versicolor
# 6.9,3.1,5.1,2.3,virginica
# 7.2,3.0,5.8,1.6,virginica
# 5.0,3.4,1.6,0.4,setosa
# 4.9,3.0,1.4,0.2,setosa
# 6.7,3.0,5.2,2.3,virginica
# 5.9,3.0,4.2,1.5,versicolor
# 5.8,2.7,5.1,1.9,virginica
# 5.7,2.8,4.5,1.3,versicolor

# %%
# !head ../data/iris_test.csv
# Out:
# Sepal.Length,Sepal.Width,Petal.Length,Petal.Width
# 4.8,3.1,1.6,0.2
# 7.2,3.2,6.0,1.8
# 4.8,3.0,1.4,0.1
# 4.8,3.0,1.4,0.3
# 6.7,3.3,5.7,2.1
# 6.9,3.2,5.7,2.3
# 6.3,2.9,5.6,1.8
# 5.5,4.2,1.4,0.2
# 6.3,3.3,6.0,2.5

# %%
train = pd.read_csv('../data/iris_train.csv')
test = pd.read_csv('../data/iris_test.csv')

# %%
train.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 0           5.0          2.0           3.5          1.0  versicolor
# 1           6.9          3.1           5.1          2.3   virginica
# 2           7.2          3.0           5.8          1.6   virginica
# 3           5.0          3.4           1.6          0.4      setosa
# 4           4.9          3.0           1.4          0.2      setosa

# %%
# notice we don't know the labels!
test.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0           4.8          3.1           1.6          0.2
# 1           7.2          3.2           6.0          1.8
# 2           4.8          3.0           1.4          0.1
# 3           4.8          3.0           1.4          0.3
# 4           6.7          3.3           5.7          2.1

# %%
train.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
# convert species to a categorical - why?
train['Species'] = pd.Categorical(train['Species'])

# %%
train.dtypes
# Out:
# Sepal.Length     float64
# Sepal.Width      float64
# Petal.Length     float64
# Petal.Width      float64
# Species         category
# dtype: object

# %%
# do we have any missing data?
train.isnull().any()
# Out:
# Sepal.Length    False
# Sepal.Width     False
# Petal.Length    False
# Petal.Width     False
# Species         False
# dtype: bool

# %%
# let's visualize the three species
plt.figure()
pd.tools.plotting.parallel_coordinates(train, 'Species');

# %% [markdown]
# ### Creating our kNN classifier!
#
# [KNN Classifier on scikit](http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier)

# %% [markdown]
# #### Parameters we care about:
#
# - n_neighbors (int): this is our k neighbors
# - weights (string): 'uniform' treats all neighbors equally; 'distance' weights neighbors by their distance, where closer neighbors have a higher weight
# - p (int): controls the power parameter, 2 for euclidean distance; 1 for manhattan distance

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# traditional to call the observations X
# and the labels y
X, y = train.iloc[:, :-1], train.iloc[:, -1]

# %%
X.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0           5.0          2.0           3.5          1.0
# 1           6.9          3.1           5.1          2.3
# 2           7.2          3.0           5.8          1.6
# 3           5.0          3.4           1.6          0.4
# 4           4.9          3.0           1.4          0.2

# %%
y.head()
# Out:
# 0    versicolor
# 1     virginica
# 2     virginica
# 3        setosa
# 4        setosa
# Name: Species, dtype: category
# Categories (3, object): [setosa, versicolor, virginica]

# %%
# starting with k=30
# this creates the classifier
knn = KNeighborsClassifier(n_neighbors=30, weights='uniform', p=2)

# %%
# execute this to fit the classifier to our data
# QUIZ: what happens during the fitting process?
knn.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=30, p=2,
#            weights='uniform')

# %%
# execute this to predict the labels for our "unseen" test data
knn.predict(test)
# Out:
# array(['setosa', 'virginica', 'setosa', 'setosa', 'virginica', 'virginica',
#        'virginica', 'setosa', 'virginica', 'setosa', 'versicolor',
#        'virginica', 'virginica', 'virginica', 'setosa', 'setosa', 'setosa',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'virginica', 'virginica', 'virginica', 'setosa',
#        'versicolor', 'virginica', 'setosa', 'setosa', 'setosa',
#        'virginica', 'setosa', 'virginica', 'setosa', 'setosa', 'virginica',
#        'setosa', 'virginica'], dtype=object)

# %% [markdown]
# ### Save your predictions to a csv called submit.csv
#
# - make sure the predictions are a 1-column dataframe with the column name Species
# - save the csv in the current directory
# - don't include row names (index)

# %%
# YOUR CODE HERE
pd.DataFrame({'Species': knn.predict(test)}).to_csv('../submit.csv', index=False)

# %% [markdown]
# ### In the example below, the script calculates the accuracy of our predictions:
#
# - accuracy is just the % of our predictions that were correct!

# %%
# run the python script called scorer.py with the
# name of the submission as an argument
# !python ../scorer.py submit.csv
# Out:
# Traceback (most recent call last):
#   File "../scorer.py", line 10, in <module>
#     submission = pd.read_csv(sys.argv[1], delimiter=',')
#   File "/Users/yunchoi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py", line 562, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/Users/yunchoi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py", line 315, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/Users/yunchoi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py", line 645, in __init__
#     self._make_engine(self.engine)
#   File "/Users/yunchoi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py", line 799, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/Users/yunchoi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py", line 1213, in __init__
#     self._reader = _parser.TextReader(src, **kwds)
#   File "pandas/parser.pyx", line 358, in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3427)
#   File "pandas/parser.pyx", line 628, in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6861)
# IOError: File submit.csv does not exist

# %% [markdown]
# # Try to get a score of 98% or higher!

# %% [markdown]
# ## Exploring scoring the algorithm in sklearn

# %%
# load the answers so we can check out work
answers = pd.read_csv('../data/answers.csv')
answers['Species'] = pd.Categorical(answers['Species'])

# %%
# to score our results against the answer key
# using the knn algorithm from sk learn
# that we created earlier, we use .score()
# .score() calculates the accuracy
print knn.score(test, answers['Species'])
# Out:
# 0.94

# %%
# use matplotlib to make a visualization showing how the score
# changes when we change n_neighbors

# YOUR CODE HERE
scores = []
n_neighbors = range(1, 101)
for k in n_neighbors:
    knn = KNeighborsClassifier(n_neighbors=k, weights='uniform', p=2)
    knn.fit(X, y)
    scores.append(knn.score(test, answers['Species']))
    
plt.plot(n_neighbors, scores);

# %%
# describe what you see in your chart

# %% [markdown]
# The accuracy peaks at around k=12 and drops off shortly thereafter. Lower values of k have less neighbors to reference, so they can be more volatile than higher values of k. Higher values of k eventually converge to just voting for the most occurring label, leading to the lower accuracy of approx 30%.

# %%
# pick a level for k that you would use and indicate why you chose it

# %% [markdown]
# I choose k=12 since it seems to perfectly fit the test data.

# %%
# does your answer seem reasonable? do you have any concerns or questions?

# %% [markdown]
# 100% accuracy seems too good to be true, but the dataset is rather small. Due to the high accuracy, I am concerned that I may be overfitting, but I am not sure how to verify that yet.

# %%
# how does the dataset play into the strengths and weaknesses of the kNN algorithm?

# %%
train.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.135046      0.845195     0.784866
# Sepal.Width      -0.135046     1.000000     -0.497769    -0.427968
# Petal.Length      0.845195    -0.497769      1.000000     0.957335
# Petal.Width       0.784866    -0.427968      0.957335     1.000000

# %% [markdown]
# We don't have a ton of features relative to the number of observations and all of our features are relevant measurements of the iris flower. The lack of irrelevant features and low amount of dimensions (aka # features) plays into the strengths of kNN. Some of the features appear to be correlated, which could hurt the performance of kNN if they are truly unnecessary. Prediction time would be an issue if the dataset were much larger.
